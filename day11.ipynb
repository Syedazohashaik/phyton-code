# %%
#linked list operations using python 
match(ch):
     case 1:start_insert()
     case 2:mid_insert()
     case 3:end_insert()
     case 4:start_delete()
     case 5:mid_delete()
     case 6:end_delete()
     case_:print("invalid choice")
class node:
    def __init__(self,data):
        self.data value
        self.next none

class linkedlist:
    def __int__(self,data):
        self .head none

def start_insert

# %%
#OPERTIONS ON LINKED LISTS
class node:
    def __init__(self,value):
        self.data=value
        self.next=None

head=node(1)
head.next=node(2)
head.next.next=node(3)
head.next.next.next=node(4)
head.next.next.next.next=node(5)

print(head.data,"-->",
head.next.data,"-->",
head.next.next.data,"-->",
head.next.next.next.data,"-->",
head.next.next.next.next.data,"-->",)
# Out:
# 1 --> 2 --> 3 --> 4 --> 5 -->

# %%
#start insert
x=int(input())
temp=node(x)
temp.next=head
head=temp
print(head.data)

#to display
print(head.data,"-->",
head.next.data,"-->",
head.next.next.data,"-->",
head.next.next.next.data,"-->",
head.next.next.next.next.data,"-->",
head.next.next.next.next.next.data,"-->")
# Out:
#  0
# 0
# 0 --> 1 --> 2 --> 3 --> 4 --> 5 -->

# %%
#end insert
x=int(input())
temp=node(x)
curr=head
if curr==None:
    head=temp
else:
    while curr.next!=None:
        curr=curr.next
    curr.next=temp 
    
#to display
curr=head
while curr!=None:
    print(curr.data,"-->",end=" ")
    curr=curr.next

# %%
class node:
    def __init__(self,value):
        self.data=value
        self.left=None
        self.right=None

    def preorder(root):
        if root==None:
            return
        print(root.data)
        preorder(root.left)
        preorder(root.right)


root=node(1)
root.left=node(2)
root.right=node(3)

root.left.left=node(4)
root.left.right=node(5)

root.right.left=node(6)
root.right.right=node(7)

preorder(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      22 root.right.left=node(6)
#      23 root.right.right=node(7)
# ---> 25 preorder(root)
#
# NameError: name 'preorder' is not defined

# %%
class node:
    def __init__(self,value):
        self.data=value
        self.left=None
        self.right=None

def preorder(root):
    if root==None:
        return
    print(root.data)
    preorder(root.left)
    preorder(root.right)


root=node(1)
root.left=node(2)
root.right=node(3)

root.left.left=node(4)
root.left.right=node(5)

root.right.left=node(6)
root.right.right=node(7)

print("preorder")
preorder(root)

def postorder(root):
    if root==None:
        return
    postorder(root.left)
    postorder(root.right)
    print(root.data,)


root=node(1)
root.left=node(2)
root.right=node(3)

root.left.left=node(4)
root.left.right=node(5)

root.right.left=node(6)
root.right.right=node(7)

print("postorder")
postorder(root)

def inorder(root):
    if root==None:
        return
    inorder(root.left)
    print(root.data)
    inorder(root.right)


root=node(1)
root.left=node(2)
root.right=node(3)

root.left.left=node(4)
root.left.right=node(5)

root.right.left=node(6)
root.right.right=node(7)

print("inorder")
inorder(root)

def levelorder(root):
    Q=[root,None]
    while Q:
        curr=Q.pop(0)
        if curr == None:
            print()
            if Q:
                Q.append(curr)
        else:
            print(curr.data,end=" ")
            if curr.left!=None:
                Q.append(curr.left)

            if curr.right!=None:
                Q.append(curr.right)
    if root==None:
        return

root=node(1)
root.left=node(2)
root.right=node(3)

root.left.left=node(4)
root.left.right=node(5)

root.right.left=node(6)
root.right.right=node(7)

print("level order")
levelorder(root)
# Out:
# preorder
# 1
# 2
# 4
# 5
# 3
# 6
# 7
# postorder
# 4
# 5
# 2
# 6
# 7
# 3
# 1
# inorder
# 4
# 2
# 5
# 1
# 6
# 3
# 7
# level order
# 1
# 2 3
# 4 5 6 7
